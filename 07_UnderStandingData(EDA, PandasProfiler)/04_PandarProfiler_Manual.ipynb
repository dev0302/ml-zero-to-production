# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df.head()

# %%
# !pip install pandas-profiling

# %%
import sys
# !{sys.executable} -m pip install fg-data-profiling
# Out:
# Collecting fg-data-profiling
#   Downloading fg_data_profiling-4.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.19.0,>=1.8 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (1.18.0)
# Collecting pandas!=1.4.0,<3.0,>1.5 (from fg-data-profiling)
#   Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib<3.12,>=3.5 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (3.11.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (3.1.6)
# Collecting visions<0.9,>=0.7.5 (from visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling)
#   Downloading visions-0.8.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.6,>=1.22 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (2.4.6)
# Collecting minify-html>=0.15.0 (from fg-data-profiling)
#   Downloading minify_html-0.18.1-cp314-cp314-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from fg-data-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from fg-data-profiling)
#   Downloading phik-0.12.5-cp314-cp314-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (2.34.2)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (4.68.2)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from fg-data-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (0.14.6)
# Collecting typeguard<5,>=4 (from fg-data-profiling)
#   Downloading typeguard-4.6.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting imagehash==4.3.2 (from fg-data-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from fg-data-profiling)
#   Downloading wordcloud-1.9.6-cp314-cp314-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from fg-data-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.68,>=0.60 in c:\Users\devma\anaconda3\Lib\site-packages (from fg-data-profiling) (0.65.1)
# Requirement already satisfied: PyWavelets in c:\Users\devma\anaconda3\Lib\site-packages (from imagehash==4.3.2->fg-data-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\Users\devma\anaconda3\Lib\site-packages (from imagehash==4.3.2->fg-data-profiling) (12.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\devma\anaconda3\Lib\site-packages (from jinja2<3.2,>=3.1.6->fg-data-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\devma\anaconda3\Lib\site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\devma\anaconda3\Lib\site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\devma\anaconda3\Lib\site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\devma\anaconda3\Lib\site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\devma\anaconda3\Lib\site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (26.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\devma\anaconda3\Lib\site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\devma\anaconda3\Lib\site-packages (from matplotlib<3.12,>=3.5->fg-data-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\Users\devma\anaconda3\Lib\site-packages (from numba<0.68,>=0.60->fg-data-profiling) (0.47.0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\devma\anaconda3\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\devma\anaconda3\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2026.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\Users\devma\anaconda3\Lib\site-packages (from phik<0.13,>=0.12.5->fg-data-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\devma\anaconda3\Lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\devma\anaconda3\Lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\devma\anaconda3\Lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\devma\anaconda3\Lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\devma\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\devma\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\devma\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\devma\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in c:\Users\devma\anaconda3\Lib\site-packages (from statsmodels<1,>=0.13.2->fg-data-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\Users\devma\anaconda3\Lib\site-packages (from tqdm<5,>=4.66.3->fg-data-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\Users\devma\anaconda3\Lib\site-packages (from visions<0.9,>=0.7.5->visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\Users\devma\anaconda3\Lib\site-packages (from visions<0.9,>=0.7.5->visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling) (3.6.1)
# Collecting puremagic (from visions<0.9,>=0.7.5->visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling)
#   Downloading puremagic-2.2.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting shapely (from visions[type_geometry,type_image_path]<0.9,>=0.7.5->fg-data-profiling)
#   Downloading shapely-2.1.2-cp314-cp314-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: six>=1.5 in c:\Users\devma\anaconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib<3.12,>=3.5->fg-data-profiling) (1.17.0)
# Downloading fg_data_profiling-4.20.0-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.1 MB 5.0 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.1 MB 4.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.1 MB 4.2 MB/s eta 0:00:03
#    ------------- -------------------------- 3.7/11.1 MB 4.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.1 MB 4.1 MB/s eta 0:00:02
#    ------------------ --------------------- 5.2/11.1 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.1 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.1 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 7.6/11.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.1 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 3.9 MB/s  0:00:02
# Downloading phik-0.12.5-cp314-cp314-win_amd64.whl (677 kB)
#    ---------------------------------------- 0.0/677.5 kB ? eta -:--:--
#    ---------------------------------------- 677.5/677.5 kB 5.3 MB/s  0:00:00
# Downloading typeguard-4.6.0-py3-none-any.whl (36 kB)
# Downloading visions-0.8.2-py3-none-any.whl (106 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp314-cp314-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.1 MB 5.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 5.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 5.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 5.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 5.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 5.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.1 MB 1.1 MB/s eta 0:00:02
#    -------------------------- ------------- 2.1/3.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 1.4 MB/s  0:00:02
# Downloading wordcloud-1.9.6-cp314-cp314-win_amd64.whl (308 kB)
# Downloading puremagic-2.2.0-py3-none-any.whl (71 kB)
# Downloading shapely-2.1.2-cp314-cp314-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.1 MB/s  0:00:00
# Installing collected packages: minify-html, filetype, typeguard, shapely, puremagic, multimethod, dacite, pandas, imagehash, wordcloud, visions, phik, fg-data-profiling
#
#    --- ------------------------------------  1/13 [filetype]
#    ------ ---------------------------------  2/13 [typeguard]
#    --------- ------------------------------  3/13 [shapely]
#    --------- ------------------------------  3/13 [shapely]
#    --------- ------------------------------  3/13 [shapely]
#    --------- ------------------------------  3/13 [shapely]
#    --------- ------------------------------  3/13 [shapely]
#    ------------ ---------------------------  4/13 [puremagic]
#   Attempting uninstall: pandas
#    ------------ ---------------------------  4/13 [puremagic]
#     Found existing installation: pandas 3.0.3
#    ------------ ---------------------------  4/13 [puremagic]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#     Uninstalling pandas-3.0.3:
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#       Successfully uninstalled pandas-3.0.3
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    --------------------- ------------------  7/13 [pandas]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------------ --- 12/13 [fg-data-profiling]
#    ------------------------------------ --- 12/13 [fg-data-profiling]
#    ------------------------------------ --- 12/13 [fg-data-profiling]
#    ------------------------------------ --- 12/13 [fg-data-profiling]
#    ------------------------------------ --- 12/13 [fg-data-profiling]
#    ------------------------------------ --- 12/13 [fg-data-profiling]
#    ---------------------------------------- 13/13 [fg-data-profiling]
#
# Successfully installed dacite-1.9.2 fg-data-profiling-4.20.0 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 pandas-2.3.3 phik-0.12.5 puremagic-2.2.0 shapely-2.1.2 typeguard-4.6.0 visions-0.8.2 wordcloud-1.9.6
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\devma\anaconda3\Lib\site-packages\~andas'.
#   You can safely remove it manually.

# %%
from data_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_file(output_file="profile_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 65.94it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
