# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df.head()

# %%
# !pip install pandas-profiling

# %%
import sys
# !{sys.executable} -m pip install fg-data-profiling

# %%
from data_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_file(output_file="profile_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 65.94it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# open : http://127.0.0.1:5500/07_UnderStandingData(EDA,%20PandasProfiler)/profile_report.html
